# %%
# We import the necessary libraries to download and manipulate the data, and to visualize it.
import pandas as pd
import yfinance as yf
import sys
import os

# Ruta absoluta a la raíz del proyecto
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
# # Moveing the variables to the top of the notebook and made it consistent with the rest of the notebooks
# ASSET = "BTC-USD"
# START_DATE = "2018-01-01"
# END_DATE = pd.Timestamp.now()
# INTERVAL = "1d"

# %%
# Removing the variables to the top of the notebook and use the config
from config import ASSETS, START_DATE, END_DATE, INTERVAL, RAW_DATA_PATH

# %%
# Download, validate and save each asset

for asset in ASSETS:

    print(f"\n{'='*60}")
    print(f"Downloading {asset}")
    print(f"{'='*60}")

    data = yf.download(
        tickers=asset,
        start=START_DATE,
        end=END_DATE,
        interval=INTERVAL,
        auto_adjust=False
    )

    # Validation
    print("\nData Info:")
    data.info()

    print("\nMissing Values:")
    print(data.isnull().sum())

    print("\nFirst 5 Rows:")
    print(data.head())

    print("\nLast 5 Rows:")
    print(data.tail())

    # Dynamic filename
    asset_name = asset.lower().replace("-", "_")

    filename = f"{RAW_DATA_PATH}/{asset_name}_{INTERVAL}_raw.csv"

    # Save CSV
    data.to_csv(filename)

    print(f"\nSaved: {filename}")
# Out:
# ============================================================
# Downloading BTC-USD
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Data Info:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 3077 entries, 2018-01-01 to 2026-06-05
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   (Adj Close, BTC-USD)  3077 non-null   float64
#  1   (Close, BTC-USD)      3077 non-null   float64
#  2   (High, BTC-USD)       3077 non-null   float64
#  3   (Low, BTC-USD)        3077 non-null   float64
#  4   (Open, BTC-USD)       3077 non-null   float64
#  5   (Volume, BTC-USD)     3077 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 168.3 KB
#
# Missing Values:
# Price      Ticker
# Adj Close  BTC-USD    0
# Close      BTC-USD    0
# High       BTC-USD    0
# Low        BTC-USD    0
# Open       BTC-USD    0
# Volume     BTC-USD    0
# dtype: int64
#
# First 5 Rows:
# Price          Adj Close         Close          High           Low  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2018-01-01  13657.200195  13657.200195  14112.200195  13154.700195
# 2018-01-02  14982.099609  14982.099609  15444.599609  13163.599609
# 2018-01-03  15201.000000  15201.000000  15572.799805  14844.500000
# 2018-01-04  15599.200195  15599.200195  15739.700195  14522.200195
# 2018-01-05  17429.500000  17429.500000  17705.199219  15202.799805
#
# Price               Open       Volume
# Ticker           BTC-USD      BTC-USD
# Date
# 2018-01-01  14112.200195  10291200000
# 2018-01-02  13625.000000  16846600192
# 2018-01-03  14978.200195  16871900160
# 2018-01-04  15270.700195  21783199744
# 2018-01-05  15477.200195  23840899072
#
# Last 5 Rows:
# Price          Adj Close         Close          High           Low  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2026-05-31  73579.687500  73579.687500  74153.500000  73315.015625
# 2026-06-01  71319.773438  71319.773438  73969.570312  70599.507812
# 2026-06-02  66703.656250  66703.656250  71334.953125  66127.265625
# 2026-06-03  64014.367188  64014.367188  67402.929688  64009.675781
# 2026-06-05  63412.019531  63412.019531  63828.003906  63015.617188
#
# Price               Open       Volume
# Ticker           BTC-USD      BTC-USD
# Date
# 2026-05-31  73753.750000  17445435650
# 2026-06-01  73580.210938  43378836121
# 2026-06-02  71321.031250  54990073882
# 2026-06-03  66694.007812  47411556213
# 2026-06-05  63812.175781  58429591552
#
# Saved: ../data/raw/btc_usd_1d_raw.csv

# %% [markdown]
# # Dataset Summary
#
# ### Source
# Yahoo Finance (BTC-USD)
#
# ### Time Range
# 2018-01-01 to 2026-06-01
#
# ### Frequency
# Daily
#
# ### Number of Observations
# 3074
#
# ### Features
# - Open
# - High
# - Low
# - Close
# - Volume
#
# ### Missing Values
# No missing values were detected.
#
# ### Data Structure
# The dataset uses a MultiIndex column structure generated by yfinance. The second level corresponds to the asset ticker (BTC-USD).
#
# ### Initial Assessment
# The dataset contains sufficient historical information to capture multiple market conditions, including bullish, bearish, and high-volatility periods. No immediate data quality issues were detected.

# %% [markdown]
# ## Future Scalability Considerations
#
# The current analysis focuses on BTC-USD. However, the project architecture should support future expansion to multiple assets.
#
# Potential configurable parameters:
#
# - Assets
# - Start date
# - End date
# - Sampling frequency
#
# Future versions should minimize hardcoded values and allow the same analysis pipeline to be executed for different assets.

# %% [markdown]
# # Conclusion
#
# The initial data collection phase was successfully completed using historical BTC-USD data obtained from Yahoo Finance.
#
# The dataset spans from 2018-01-01 to 2026-06-01 and contains 3,074 daily observations with no missing values detected. The available variables include Open, High, Low, Close, and Volume, providing sufficient information for future feature engineering and market regime analysis.
#
# A MultiIndex column structure was identified during the inspection process. This structure is generated automatically by yfinance to support multi-asset downloads. Since the current analysis focuses on a single asset (BTC-USD), the second index level is redundant for this phase but remains an important consideration for future project scalability.
#
# Based on the data quality assessment, the dataset is suitable for exploratory analysis and subsequent machine learning stages.
